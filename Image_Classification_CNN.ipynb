# %%
import tensorflow as tf

print("TensorFlow Version:", tf.__version__)
# Out:
# TensorFlow Version: 2.21.0

# %%
import matplotlib.pyplot as plt
import numpy as np

print("Libraries Loaded Successfully!")
# Out:
# Libraries Loaded Successfully!

# %%
import tensorflow as tf

datasets = tf.keras.utils.image_dataset_from_directory(
    "datasets",
    image_size=(128, 128),
    batch_size=32
)

print("Datasets Loaded Successfully!")
print("Classes:", dataset.class_names)
# Out:
# Found 24952 files belonging to 2 classes.
# Dataset Loaded Successfully!
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 10
#       6     batch_size=32
#       7 )
#       8
#       9 print("Dataset Loaded Successfully!")
# ---> 10 print("Classes:", dataset.class_names)
#
# NameError: name 'dataset' is not defined

# %%
import os
print(os.getcwd())

# %%
import tensorflow as tf

dataset = tf.keras.utils.image_dataset_from_directory(
    "./dataset",
    image_size=(128, 128),
    batch_size=32
)

print("Dataset Loaded Successfully!")
print("Classes:", dataset.class_names)

# %%
import os

print("Current Folder:")
print(os.getcwd())

# %%
import os

print(os.path.exists("dataset"))
print(os.listdir("dataset"))

# %%
import os

print(os.listdir())

# %%
import tensorflow as tf

dataset = tf.keras.utils.image_dataset_from_directory(
    "datasets",
    image_size=(128,128),
    batch_size=32
)

print("Dataset Loaded Successfully!")
print("Classes:", dataset.class_names)

# %%
import matplotlib.pyplot as plt

for images, labels in dataset.take(1):
    plt.figure(figsize=(10,10))

    for i in range(9):
        ax = plt.subplot(3,3,i+1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(dataset.class_names[labels[i]])
        plt.axis("off")

plt.show()

# %%
model = tf.keras.Sequential([
    tf.keras.Input(shape=(128,128,3)),

    tf.keras.layers.Rescaling(1./255),

    tf.keras.layers.Conv2D(16,3,activation='relu'),
    tf.keras.layers.MaxPooling2D(),

    tf.keras.layers.Conv2D(32,3,activation='relu'),
    tf.keras.layers.MaxPooling2D(),

    tf.keras.layers.Flatten(),

    tf.keras.layers.Dense(128,activation='relu'),

    tf.keras.layers.Dense(2,activation='softmax')
])

model.summary()

# %%
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

print("Model Compiled Successfully!")

# %%
history = model.fit(
    dataset,
    epochs=3
)

# %%
from PIL import Image
import os

for folder in ["datasets/Cat", "datasets/Dog"]:
    print("Checking", folder)

    for file in os.listdir(folder):
        path = os.path.join(folder, file)

        try:
            img = Image.open(path)
            img.verify()
        except Exception as e:
            print("BAD FILE:", path)
            print("ERROR:", e)
            break

# %%
import os

os.remove("datasets/Cat/Thumbs.db")
os.remove("datasets/Dog/Thumbs.db")

print("Thumbs.db files deleted!")

# %%
import os

print("Thumbs.db" in os.listdir("datasets/Cat"))
print("Thumbs.db" in os.listdir("datasets/Dog"))

# %%
import tensorflow as tf

dataset = tf.keras.utils.image_dataset_from_directory(
    "datasets",
    image_size=(128,128),
    batch_size=32
)

print("Dataset Loaded Successfully!")

# %%
history = model.fit(
    dataset,
    epochs=3
)

# %%
from PIL import Image
import os

bad_files = []

for folder in ["datasets/Cat", "datasets/Dog"]:
    print("Checking", folder)

    for file in os.listdir(folder):
        path = os.path.join(folder, file)

        try:
            with Image.open(path) as img:
                img.load()
        except Exception as e:
            bad_files.append((path, str(e)))

print("Total bad files:", len(bad_files))

for f, err in bad_files[:20]:
    print(f)
    print("Error:", err)
    print("-" * 50)

# %%
import tensorflow as tf

dataset = tf.keras.utils.image_dataset_from_directory(
    "datasets",
    image_size=(128,128),
    batch_size=1,
    shuffle=False
)

count = 0

for images, labels in dataset:
    count += 1

print("All images loaded successfully:", count)

# %%
import tensorflow as tf
import os

cat_folder = "datasets/Cat"

files = sorted(os.listdir(cat_folder))

for i, file in enumerate(files):
    path = os.path.join(cat_folder, file)

    try:
        img = tf.io.read_file(path)
        img = tf.image.decode_jpeg(img)

    except Exception as e:
        print("BAD FILE FOUND:")
        print(path)
        print(e)
        break

print("Finished checking Cats")

# %%
import os

os.remove("datasets/Cat/10073.jpg")

print("Bad file deleted!")

# %%
import tensorflow as tf
import os

for folder in ["datasets/Cat", "datasets/Dog"]:

    print(f"\nChecking {folder}")

    for file in os.listdir(folder):

        path = os.path.join(folder, file)

        try:
            img = tf.io.read_file(path)
            tf.io.decode_image(img)

        except Exception as e:
            print("BAD FILE:", path)

# %%
import os

bad_files = [
    "datasets/Cat/4351.jpg",
    "datasets/Dog/11233.jpg",
    "datasets/Dog/11912.jpg",
    "datasets/Dog/2317.jpg",
    "datasets/Dog/2494.jpg",
    "datasets/Dog/9500.jpg"
]

for file in bad_files:
    if os.path.exists(file):
        os.remove(file)
        print("Deleted:", file)

print("All bad files removed!")

# %%
import tensorflow as tf

dataset = tf.keras.utils.image_dataset_from_directory(
    "datasets",
    image_size=(128,128),
    batch_size=32
)

print("Dataset Loaded Successfully!")

# %%
history = model.fit(
    dataset,
    epochs=3
)

# %%
dataset = dataset.apply(
    tf.data.experimental.ignore_errors()
)

# %%
dataset = dataset.ignore_errors()

# %%
history = model.fit(
    dataset,
    epochs=3
)

# %%
model.save("cats_dogs_model.keras")

print("Model Saved Successfully!")

# %%
import numpy as np
from tensorflow.keras.preprocessing import image

img = image.load_img("test.jpg", target_size=(128,128))
img_array = image.img_to_array(img)
img_array = np.expand_dims(img_array, axis=0)

prediction = model.predict(img_array)

if np.argmax(prediction) == 0:
    print("Prediction: Cat")
else:
    print("Prediction: Dog")

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['accuracy'])
plt.title("Model Accuracy")
plt.ylabel("Accuracy")
plt.xlabel("Epoch")
plt.show()

# %%
history = model.fit(
    dataset,
    epochs=3
)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.title("Training Accuracy")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 4
#       1 import matplotlib.pyplot as plt
#       2
#       3 plt.figure(figsize=(8,5))
# ----> 4 plt.plot(history.history['accuracy'], label='Training Accuracy')
#       5 plt.xlabel("Epoch")
#       6 plt.ylabel("Accuracy")
#       7 plt.title("Training Accuracy")
#
# NameError: name 'history' is not defined

# %%
model.fit(
    dataset,
    epochs=3
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 model.fit(
#       2     dataset,
#       3     epochs=3
#       4 )
#
# NameError: name 'model' is not defined
